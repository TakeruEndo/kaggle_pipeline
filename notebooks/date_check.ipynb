# %%
import pandas as pd
import numpy as np
import seaborn as sns
# データ可視化ライブラリ
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("../data/raw/train.csv")
test = pd.read_csv("../data/raw/test.csv")

# %%
train['displacement'].describe()
# Out:
# count    199.000000
# mean     183.311558
# std       98.400457
# min       71.000000
# 25%       98.000000
# 50%      140.000000
# 75%      250.000000
# max      454.000000
# Name: displacement, dtype: float64

# %%
train['weight'].describe()
# Out:
# count     199.000000
# mean     2883.839196
# std       819.766870
# min      1613.000000
# 25%      2217.500000
# 50%      2702.000000
# 75%      3426.500000
# max      5140.000000
# Name: weight, dtype: float64

# %%
train.tail()
# Out:
#       id   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 194  384  40.8          4          85.0      65.00  2110.0          19.2
# 195  385  20.2          8         302.0      139.0  3570.0          12.8
# 196  387  16.0          8         304.0      150.0  3433.0          12.0
# 197  395  43.4          4          90.0      48.00  2335.0          23.7
# 198  396  26.0          4          98.0      90.00  2265.0          15.5
#
#      model year  origin              car name
# 194          80       3            datsun 210
# 195          78       1  mercury monarch ghia
# 196          70       1         amc rebel sst
# 197          80       2    vw dasher (diesel)
# 198          73       2  fiat 124 sport coupe

# %%
#scatter plot grlivarea/salepriceaa
data = pd.concat([train['displacement'], train['id']], axis=1)
data.plot.scatter(x='id', y='displacement', ylim=(0,500), xlim=(0,200));

# %%
#scatter plot grlivarea/salepriceaa
data = pd.concat([train['weight'], train['id']], axis=1)
data.plot.scatter(x='id', y='weight', ylim=(0,5200), xlim=(0,200));

# %%
sns.pairplot(train[["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year"]])
plt.show()

# %%
train['mpg'].describe()
# Out:
# count    199.000000
# mean      24.307035
# std        7.797665
# min        9.000000
# 25%       18.000000
# 50%       24.000000
# 75%       30.500000
# max       44.600000
# Name: mpg, dtype: float64

# %%
train['origin'].unique()
# Out:
# array([1, 2, 3])

# %%
train['cylinders'].unique()
# Out:
# array([4, 6, 8, 5, 3])
